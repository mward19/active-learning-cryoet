# %%
from visualize_voxels import visualize

def viz(image, marks=[]):
    visualize(
        image, 
        marks=marks, 
        minval=np.percentile(image, 0.1),
        maxval=np.percentile(image, 99.9)
    )

import os
import numpy as np
import json

# %%
data_path = '/home/mward19/nobackup/autodelete/fm-data-2/tomo-10233/tiles/tile-0-1-1'
image = np.load(os.path.join(data_path, 'tile.npy'))
with open(os.path.join(data_path, 'points.json'), 'r') as f:
    points = json.load(f)
points

# %%
image.shape

# %%
viz(
    image, 
    marks=points
)

# %%
data_path = '/home/mward19/nobackup/autodelete/fm-data-2/tomo-10233/tiles/tile-0-0-1'
image = np.load(os.path.join(data_path, 'tile.npy'))
viz(image)
# image.shape
